# %% [markdown]
# # Semana 3

# %% [markdown]
# # Anonimato na Internet: Tor e Deep Web

# %% [markdown]
# # Roteamento na Internet
#
# Sempre é possível identificar IPs dos pacotes
#  - Origem enxerga destino e vice-versa
#  - Roteadores intermediários enxergam IPs
#
# Soluções de segurança tradicionais protegem dados, não IPs
#  - Ex.: HTTPS, TLS, SSH, SFTP/SCP etc.
#
# Como melhorar a privacidade?
#  - Disfarçar a origem e o destino dos dados
#
#  ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Roteamento com privacidade
#
# Roteamento aleatorizado: “anonimizador” se passa pela origem das mensagens
#  - Várias técnicas: Crowds, Freenet, Onion routing
#  - Nem destino ou entidade monitorando a rede consegue identificar a origem real da mensagem
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Onion routing: Ideia
#
# Onion Routing: origem recorre a sequência aleatória de “roteadores” (usuários finais)
#  - Alguns honestos, outros sob controle de atacantes
#  - Origem controla o comprimento do caminho
#  - Dados e metadados são cifrados
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Tor: Onion 2ª geração
#
# Segunda geração do Onion Routing
#  - Disponível: http://tor.eff.org
#
# Ativo desde Outubro de 2003
#  - Diversos nós espalhados pelo mundo todo
#  - Milhares de usuários
#  - Clientes de “fácil uso” (plugins, Tor Browser)
#  - Navegação anônima e gratuita

# %% [markdown]
# # Tor: Funcionamento
#
# ![image.png](data:image/png;base64,...)
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![picasion.com_0e433c316926a868b2cd245d1298569a.gif](data:image/gif;base64,...)

# %% [markdown]
# # Tor: Serviços escondidos
#
#
# Mas e a proteção do IP dos servidores?
# - Origem enxerga IP dos destino
# - Mecanismo extra do Tor: serviços escondidos (.onion)
#   - Protege geolocalização: contra ataques físicos
#   - Protege IP: contra ataques lógicos (negação de serviço)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Resultado:
# - Servidor não enxerga IP de cliente
# - Cliente não enxerga IP de servidor
# - Nós intermediários não identificam quem está se comunicando
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Tor, web e “Deep Web”: Indexação
#
# Web Crawling: indexação automática dos sites
#  - Construção da base de dados dos sites de busca
#
# Web spiders (ou crawlers): programas de computador que automatizam a indexação
#  - Visitam páginas e indexam texto visível e metadados
#  - Seguem links encontrados: “navegam” na web e descobrem novos sites
#  - Podem executar repetidamente: identificam modificações em páginas já visitadas
#
# “Deep web”: conteúdo não indexado por máquinas de busca tradicionais
#  - Conteúdo gerado dinamicamente (ex.: Javascript)
#  - Páginas para as quais não existem links em sites já indexados
#  - Conteúdo em sites privados ou de acesso restrito
#    - Exige login ou forma de acesso específico (ex.: Tor)
#  - Texto embutido em arquivos multimídia
#
#
#
#  "Especula-se que a Deep Web é cerca de 400-500 vezes maior do que a Surface Web".
# UC Berkley, 2001

# %% [markdown]
# ![deep-web.jpg](data:image/jpeg;base64,...)
