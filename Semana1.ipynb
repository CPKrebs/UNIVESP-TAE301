# %% [markdown]
# # Semana 1

# %% [markdown]
# # Sistemas distribuídos: P2P e DHT

# %% [markdown]
# # Sistemas distribuídos
# Vários sistemas que não se resumem a uma máquina
#
#
# ![image.png](data:image/png;base64,...)
#
# Mas podem envolver:
#
# - Várias máquinas colaborando em rede: P2P
# - Várias máquinas alocadas sob demanda: nuvem
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # P2P vs. Cliente-servidor
#
# Gargalos: servidor, conexões do servidor e conexões dos clientes
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# P2P: colaboração entre clientes
# - Explora conexões alternativas
# - Alivia carga no servidor
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # P2P: Características
#
# Nós com responsabilidades similares:
# - Se comunicam diretamente (conexões lógicas)
# - Fornecem e usam recursos do sistema
#
#
# Administração pode ser complexa:
# - Entrada e saída frequente de nós no sistema
# - Necessidade de localizar nós e recursos na rede
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # P2P: Organização
#
# Pode ser puramente descentralizado
# - Nós realizam as mesmas tarefas, sem coordenação central do sistema
# - Alguns desafios: consistência dos dados, gerenciamento e custos de comunicação
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Pode haver servidor auxiliar
# - Facilita interação entre nós: buscas de conteúdo e localização de nós (endereço IP)
# - Comunicação direta entre nós após interação com servidor
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Pode haver super nós;
# - Assumem papel mais importante que outros
# - Auxiliam na indexação de nós/conteúdos diretamente ligados a eles
#  - Como “mini servidores”
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # P2P: Estratégia de busca
#
# Busca não estruturada:
# - Dados distribuídos aleatoriamente entre nós;
# - Localização dos dados não tem relação com a organização da rede;
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Busca estruturada:
# - Topologia da rede bem definida;
# - Dados (ou referências para os dados) colocados em locais específicos;
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Busca estruturada
#
# Tabela hash: mapeia “chaves” em “valores”
#
#
# - Chave = hash(dado)
#
# - Put (chave, valor): insere valor na tabela
#
# - Get (chave): recupera valor da tabela
#
# Permite localizar dados de forma eficiente
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Busca estruturada: DHT
# Tabela hash distribuídas (DHT): similar a tabela hash, mas espalhada na rede;
# - Chave = hash(dado) = 27
# - Buscar (chave):  IP_25
# - Rotear (IP_25, PUT, chave, IP_34)
# - Rotear (IP_25, GET, chave): IP_34
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Resumo: exemplos
#
# ![image.png](data:image/png;base64,...)
